# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams

import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %% [markdown]
# ### Defining plot color

# %%
x = range(1,10)
y = [1,2,3,4,0.5,4,3,2,1]

plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
wide = [0.5,0.5,0.5,0.9,0.9,0.9,0.5,0.5,0.5]
color = ['salmon']

plt.bar(x,y,width=wide,color=color,align='center')
# Out:
# <BarContainer object of 9 artists>

# %%
address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv'

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
mpg = cars['mpg']

# %%
df = cars[['cyl','mpg','wt']]
df.plot()
# Out:
# <Axes: >

# %%
color_theme = ['darkgray', 'lightsalmon', 'powderblue']
df.plot(color=color_theme)
# Out:
# <Axes: >

# %%
z = [1,2,3,4,0.5]
plt.pie(z)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
color_theme = ['#A9A9A9']
plt.pie(z, colors='color_theme')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 color_theme = ['#A9A9A9']
# ----> 2 plt.pie(z, colors='color_theme')
#
#     [... skipping hidden 1 frame]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/pyplot.py:3989, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3966 @_copy_docstring_and_deprecators(Axes.pie)
#    3967 def pie(
#    3968     x: ArrayLike,
#    (...)   3987     data: DataParamType = None,
#    3988 ) -> PieContainer:
# -> 3989     return gca().pie(
#    3990         x,
#    3991         explode=explode,
#    3992         labels=labels,
#    3993         colors=colors,
#    3994         autopct=autopct,
#    3995         pctdistance=pctdistance,
#    3996         shadow=shadow,
#    3997         labeldistance=labeldistance,
#    3998         startangle=startangle,
#    3999         radius=radius,
#    4000         counterclock=counterclock,
#    4001         wedgeprops=wedgeprops,
#    4002         textprops=textprops,
#    4003         center=center,
#    4004         frame=frame,
#    4005         rotatelabels=rotatelabels,
#    4006         normalize=normalize,
#    4007         hatch=hatch,
#    4008         **({"data": data} if data is not None else {}),
#    4009     )
#
#     [... skipping hidden 2 frame]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/axes/_axes.py:3712, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3709 x_pos += expl * math.cos(thetam)
#    3710 y_pos += expl * math.sin(thetam)
# -> 3712 w = mpatches.Wedge((x_pos, y_pos), radius, 360. * min(theta1, theta2),
#    3713                    360. * max(theta1, theta2),
#    3714                    facecolor=get_next_color(),
#    3715                    hatch=next(hatch_cycle),
#    3716                    clip_on=False,
#    3717                    label=label)
#    3718 w.set(**wedgeprops)
#    3719 slices.append(w)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/patches.py:1353, in Wedge.__init__(self, center, r, theta1, theta2, width, **kwargs)
#    1341 @_docstring.interpd
#    1342 def __init__(self, center, r, theta1, theta2, *, width=None, **kwargs):
#    1343     """
#    1344     A wedge centered at *x*, *y* center with radius *r* that
#    1345     sweeps *theta1* to *theta2* (in degrees).  If *width* is given,
#    (...)   1351     %(Patch:kwdoc)s
#    1352     """
# -> 1353     super().__init__(**kwargs)
#    1354     self.center = center
#    1355     self.r, self.width = r, width
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/patches.py:87, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, hatchcolor, edgegapcolor, **kwargs)
#      85     self.set_edgecolor(edgecolor)
#      86     self.set_hatchcolor(hatchcolor)
# ---> 87     self.set_facecolor(facecolor)
#      89 self._linewidth = 0
#      90 self._unscaled_dash_pattern = (0, None)  # offset, dash
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/patches.py:411, in Patch.set_facecolor(self, color)
#     403 """
#     404 Set the patch face color.
#     405
#    (...)    408 color : :mpltype:`color` or None
#     409 """
#     410 self._original_facecolor = color
# --> 411 self._set_facecolor(color)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/patches.py:399, in Patch._set_facecolor(self, color)
#     397 color = mpl._val_or_rc(color, 'patch.facecolor')
#     398 alpha = self._alpha if self._fill else 0
# --> 399 self._facecolor = colors.to_rgba(color, alpha)
#     400 self.stale = True
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/colors.py:345, in to_rgba(c, alpha)
#     343     rgba = None
#     344 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 345     rgba = _to_rgba_no_colorcycle(c, alpha)
#     346     try:
#     347         _colors_full_map.cache[c, alpha] = rgba
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/colors.py:413, in _to_rgba_no_colorcycle(c, alpha)
#     409             raise ValueError(
#     410                 f"Invalid string grayscale value {orig_c!r}. "
#     411                 f"Value must be within 0-1 range")
#     412         return c, c, c, alpha if alpha is not None else 1.
# --> 413     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     414 # turn 2-D array into 1-D array
#     415 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'o'

# %% [markdown]
# ### Customizing line styles

# %%
x1 = range(1,10)
y1 = [9,8,7,6,5,4,3,2,1]
plt.plot(x,y)
plt.plot(x1,y1)

# %%
plt.plot(x,y, ls='solid', lw=5)
plt.plot(x1,y1, ls='--', lw=10)

# %% [markdown]
# ### Setting plot markers

# %%
plt.plot(x,y, marker='1', mew=20)
plt.plot(x1,y1, marker='+', mew=15)
